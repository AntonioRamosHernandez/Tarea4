# %%
# Ramos Hernández Antonio

import matplotlib.pyplot as plt
import math
def biseccion():

  xl= [5.0] #Lista que ira almacenando los valores del punto inicial/punto bajo, por iteración 
  xr=[] #Lista que ira almacenando los valores de la raiz por iteración 
  xu=[7.0] #Lista que ira almacenando los valores del punto final/punto alto, por iteración 
  fxl=[] #Lista que ira almacenando los valores de las funciones de punto inicial/punto, bajo por iteración 
  fxr=[] #Lista que ira almacenando los valores de las funciones de punto inicial/punto bajo por iteración 
  fxu=[] #Lista que ira almacenando los valores de las funciones de punto final/punto alto por iteración 
  Ea=0.0 #El valor de error aproximado iniciado en 0.0 por numero flotante
  EaTerminado = 0 #Variable auxiliar que me sirve para terminar el proceso que realice en un bucle y se cumpla la condición de 0.001
  i=0 #Variable que me servirá como indice en las listas y de apoyo en los bucles
  
  #Es la iteración 0 para iniciar y verificar con los intervalos f(x) y f(y) si existe o no una raiz
  fxl.append((-0.5*(xl[i]**2))+(2.5*xl[i])+4.5) 
  fxu.append((-0.5*(xu[i]**2))+(2.5*xu[i])+4.5)

  if (fxl[0]*fxu[0]<0): #Comprueba si existe una raiz en el intervalo
    print('Existe la raiz en este intervalo')#Me verifica que si existe una raiz
    #Aqui inicia el proceso y las operaciones de cada iteración
    while (EaTerminado==0): 
      print('Iterador '+ str(i)) #Muestra las veces que se han hecho iteraciones en el bucle

      xr.append((xl[i] + xu[i])/2.0) #Va agregando las raices por cada iteración Biseccion
      #xr.append(((fxl[i]*xu[i])-(fxu[i]*xl[i]))/(fxl[i]-fxu[i])) #Va agregando las raices por cada iteración Falsa Posicion
      
      fxr.append((-0.5*(xr[i]**2))+(2.5*xr[i])+4.5)

      #Muestra los valores que se van agregando a las listas de xr(las raices que se van almacenando en cada iteración)
      #también xl, xu y sus respectivas funciones fxr, fxl, fxu. Me sirve para ir verificando cada iteración.
      print('xr: '+str(xr))
      print('xl: '+str(xl))
      print('xu: '+str(xu))
      print('fxr: '+str(fxr))
      print('fxl: '+str(fxl))
      print('fxu: '+str(fxu))
      ##################################################################################################################
      #Primero verifica si ya hubo una primera iteración con el valor de i
      if (i>0): 
        #print('Ya se puede obtener Ea') Mensaje que me ayudaba a verificar que el Ea estaba funcionando
        Ea=((xr[i]-xr[i-1])/xr[i])#Operación para obtener el valor error
    
        if(Ea<0): 
          Ea=abs(Ea)
        if (Ea<0.00001): #Esta condición es la más importante porque verificará y terminara el bucle cuando el valor error se haya cumplido
          EaTerminado=1 #Manda el valor de 1 para terminar el bucle
      
      #Verifica si se encuentra de lado izquierdo o derecho siempre y cuando sea menor a 0
      if (fxl[i]*fxr[i]<0):
        print('fxl fxr')
        i+=1
        xl.append(xl[i-1])
        xu.append(xr[i-1])
      else:
        if (fxr[i]*fxu[i]<0):
          print('fxr fxu')
          i+=1
          xl.append(xr[i-1])
          xu.append(xu[i-1])
        else:
          print("Ninguno de lossssssssss 2")
      ######################################################################################
      fxl.append((-0.5*(xl[i]**2))+(2.5*xl[i])+4.5) #Agrega los proximos valores de la función del punto inicial/ punto fbajo
      fxu.append((-0.5*(xu[i]**2))+(2.5*xu[i])+4.5) #Agrega los proximos valores de la función del punto final/ punto alto
      
      print('Ea '+str(Ea)) #Muestra el valor de el valor de error que se ha obtenido en cada iteración y verificar si esta funcionando bien
      print() #Espacio
      
  else:
    print('No existe ninguna raiz en el intervalo') #No hace ningun proceso si no existe una raiz en el intervalo
    

  #Funciones que llama plt para poder Mostrar la grafica usando los valores en 'y', al igual que los valores en la coordenada x usando la raiz para ver su
  # comportamiento. Y muestra información alrededor de la grafica
  plt.title("Ejercicio 1 Metodo Biseccion", fontsize = 22)
  plt.xlabel("Valores en x", fontsize = 14)
  plt.ylabel("Valores en y", fontsize = 14) 
  plt.plot(xr)
  plt.show()


#Manda a llamar la funcion del metodo de bisección
biseccion()
# Out:
# Existe la raiz en este intervalo
# Iterador 0
# xr: [6.0]
# xl: [5.0]
# xu: [7.0]
# fxr: [1.5]
# fxl: [4.5]
# fxu: [-2.5]
# fxr fxu
# Ea 0.0
#
# Iterador 1
# xr: [6.0, 6.5]
# xl: [5.0, 6.0]
# xu: [7.0, 7.0]
# fxr: [1.5, -0.375]
# fxl: [4.5, 1.5]
# fxu: [-2.5, -2.5]
# fxl fxr
# Ea 0.07692307692307693
#
# Iterador 2
# xr: [6.0, 6.5, 6.25]
# xl: [5.0, 6.0, 6.0]
# xu: [7.0, 7.0, 6.5]
# fxr: [1.5, -0.375, 0.59375]
# fxl: [4.5, 1.5, 1.5]
# fxu: [-2.5, -2.5, -0.375]
# fxr fxu
# Ea 0.04
#
# Iterador 3
# xr: [6.0, 6.5, 6.25, 6.375]
# xl: [5.0, 6.0, 6.0, 6.25]
# xu: [7.0, 7.0, 6.5, 6.5]
# fxr: [1.5, -0.375, 0.59375, 0.1171875]
# fxl: [4.5, 1.5, 1.5, 0.59375]
# fxu: [-2.5, -2.5, -0.375, -0.375]
# fxr fxu
# Ea 0.0196078431372549
#
# Iterador 4
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375]
# fxl fxr
# Ea 0.009708737864077669
#
# Iterador 5
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125]
# fxl fxr
# Ea 0.004878048780487805
#
# Iterador 6
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125]
# fxr fxu
# Ea 0.0024449877750611247
#
# Iterador 7
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125, -0.00439453125]
# fxr fxu
# Ea 0.001221001221001221
#
# Iterador 8
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375, 6.40234375]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625, 6.3984375]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625, 6.40625]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875, 0.01085662841796875]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875, 0.026092529296875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125, -0.00439453125, -0.00439453125]
# fxr fxu
# Ea 0.0006101281269066504
#
# Iterador 9
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375, 6.40234375, 6.404296875]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625, 6.3984375, 6.40234375]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625, 6.40625, 6.40625]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875, 0.026092529296875, 0.01085662841796875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125, -0.00439453125, -0.00439453125, -0.00439453125]
# fxr fxu
# Ea 0.0003049710277523635
#
# Iterador 10
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375, 6.40234375, 6.404296875, 6.4052734375]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625, 6.3984375, 6.40234375, 6.404296875]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625, 6.40625, 6.40625, 6.40625]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875, -0.0005803108215332031]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125, -0.00439453125, -0.00439453125, -0.00439453125, -0.00439453125]
# fxl fxr
# Ea 0.00015246226558926666
#
# Iterador 11
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375, 6.40234375, 6.404296875, 6.4052734375, 6.40478515625]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625, 6.3984375, 6.40234375, 6.404296875, 6.404296875]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625, 6.40625, 6.40625, 6.40625, 6.4052734375]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875, -0.0005803108215332031, 0.001326441764831543]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875, 0.0032329559326171875]
# fxu: [-2.5, -2.5, -0.375, -0.375, -0.375, -0.126953125, -0.00439453125, -0.00439453125, -0.00439453125, -0.00439453125, -0.00439453125, -0.0005803108215332031]
# fxr fxu
# Ea 7.623694442326752e-05
#
# Iterador 12
# xr: [6.0, 6.5, 6.25, 6.375, 6.4375, 6.40625, 6.390625, 6.3984375, 6.40234375, 6.404296875, 6.4052734375, 6.40478515625, 6.405029296875]
# xl: [5.0, 6.0, 6.0, 6.25, 6.375, 6.375, 6.375, 6.390625, 6.3984375, 6.40234375, 6.404296875, 6.404296875, 6.40478515625]
# xu: [7.0, 7.0, 6.5, 6.5, 6.5, 6.4375, 6.40625, 6.40625, 6.40625, 6.40625, 6.40625, 6.4052734375, 6.4052734375]
# fxr: [1.5, -0.375, 0.59375, 0.1171875, -0.126953125, -0.00439453125, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875, -0.0005803108215332031, 0.001326441764831543, 0.0003730952739715576]
# fxl: [4.5, 1.5, 1.5, 0.59375, 0.1171875, 0.1171875, 0.1171875, 0.0565185546875, 0.026092529296875, 0.01085662841796875, 0.0032329559326171875, 0.0032329559326171875, 0.001326441764831543]
